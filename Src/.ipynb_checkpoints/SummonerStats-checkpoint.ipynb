# %%
from selenium import webdriver # driver de selenium
import time   # para manejar tiempo
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By   # para buscar segun tag, id, class, etc...
from selenium.webdriver.support.ui import WebDriverWait   # es para esperar
#from selenium.webdriver.support import expected_conditions as EC  # condiciones esperadas...
from selenium.webdriver import ActionChains as AC   # acciones encadenadas, rollo doble click
#from selenium.webdriver.common.keys import Keys  # manejar teclas
import re
import numpy as np
import asyncio
from joblib import Parallel, delayed
import multiprocessing as mp
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import requests
from datetime import datetime

import mysql.connector as conn
from sqlalchemy import create_engine

# %%
from selenium.webdriver.chrome.options import Options

opciones=Options()

# quita la bandera de ser robot
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False   # si True, no aparece la ventana (headless=no visible)

opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_extension('driver/adblock.crx')       # adblocker

#opciones.add_argument('user-data-dir=selenium')    # mantiene las coockies
opciones.add_argument('--incognito')              # incognito
#opciones.add_argument('--no-proxy-server')                 # sin proxy
#opciones.add_argument('proxy-server=106.122.8.54:3128')    # proxy custom

# %%
#funciones de limpieza para aplicar sobre los valores numericos que tienen letras o simbolos
def quitaletras(x):    
    return x[:-2]
def quitaletra(x):
    return x[:-1]
def quitaespacios(x):
    return str(x).replace(' ','')

def horita(x):
    x=x.replace('m','')
    x=x.replace('s','')
    return x

# %%
#funcion para recuperar uno por uno el perfil del link de jugadore que se le pase por parametro
def summoners(link):
    
    driver=webdriver.Chrome(PATH, options=opciones)
    driver.get(link)
    time.sleep(10)
  
    jugadores=[]
    try:
        texto=driver.find_element(By.XPATH, '//*[@id="qc-cmp2-ui"]/div[2]/div/button[2]') #cookies
        texto.click()
        time.sleep(5)
    except:
        pass
    #PLAYER NAME
    jugadores.append(driver.find_element(By.XPATH, '//*[@id="content-header"]/div[1]/div/div[1]/div[2]/div[2]/span').text)
    #PLAYER POINTS
    jugadores.append(driver.find_element(By.XPATH, '//*[@id="content-container"]/div[1]/div[1]/div[2]/div[2]/div[2]').text)
    #WIN/LOST
    aux=driver.find_element(By.XPATH, '//*[@id="content-container"]/div[1]/div[1]/div[2]/div[3]/div[1]').text
    aux=aux.split(' ')
    jugadores.append(aux[0])
    jugadores.append(aux[1])
  
    driver.quit()
    time.sleep(1)
    #devolvemos una lista con los datos del jugador. Posteriormente en la llamada PARALEL, guardamos la lista en una 
    #lista independiente, que sera nuestro SUMMONERS
    return jugadores

# %%
#funcion que devuelve las estadisticas de las partidas por jugador
#def partidasjugadas(link):
#    driver=webdriver.Chrome(PATH, options=opciones)
#    driver.get(link)
#    time.sleep(10)
#    
#    match=[]
#    nombrecito=driver.find_element(By.CLASS_NAME,'summoner-name').text
#    try:
#        texto=driver.find_element(By.XPATH, '//*[@id="qc-cmp2-ui"]/div[2]/div/button[2]') #cookies
#        texto.click()
#        time.sleep(5)
#    except:
#        pass
#    #cambio de idioma
#    texto=driver.find_element(By.XPATH, '//*[@id="__next"]/header/div[1]/div[2]/div[2]/div/button')
#    texto.click()
#    time.sleep(2)
#    texto=driver.find_element(By.XPATH, '//*[@id="__next"]/header/div[1]/div[2]/div[2]/div/div/button[1]')
#    texto.click()
#    time.sleep(2)
#    #pestaña de soloQ
#    texto=driver.find_element(By.XPATH, '//*[@id="content-container"]/div[2]/div[1]/ul/li[2]/button')
#    texto.click()
#    time.sleep(5)
#    
#    #seleccion de partidas
#    matches=driver.find_elements(By.CLASS_NAME, 'css-1qq23jn')
#    for m in matches:
#        temp=[]
#        temp.append(nombrecito)
#        date=m.find_element(By.CLASS_NAME, 'time-stamp').text #dia y hora de la partida
#        #    texto.click()
#        #    time.sleep(1)
#        #    texto.click()
#        temp.append(m.find_element(By.CLASS_NAME, 'result').text) #resultado de la partida
#        temp.append(m.find_element(By.CLASS_NAME, 'length').text.replace(' ',':')) #duracion de la partida
#        kp=re.findall(r'[0-9%]+',(m.find_element(By.CLASS_NAME, 'p-kill').text))#kill participation
#        temp.append(kp[0])
#        #nombre del campeon
#        temp.append(m.find_element(By.CLASS_NAME, 'champion').find_element(By.TAG_NAME,'div').find_element(By.TAG_NAME,'img').get_attribute('alt'))
#        #objetos
#        for i in m.find_element(By.CLASS_NAME,'items').find_elements(By.TAG_NAME,'li'): #items
#            try:
#                temp.append(i.find_element(By.TAG_NAME,'img').get_attribute('alt'))
#            except:
#                temp.append('null')
#        aux=m.find_element(By.CLASS_NAME,'k-d-a').text.split('/')#kda
#        for e in aux:
#            temp.append(e)
#
#        cs=re.findall(r' [\d]+',(m.find_element(By.CLASS_NAME,'cs').text)) #cs
#        temp.append(cs[0].replace(' ',''))     
#        match.append(temp)
#    return match
#    driver.quit()

# %%
from webdriver_manager.chrome import ChromeDriverManager
PATH=ChromeDriverManager().install()
URL='https://www.op.gg/'

driver=webdriver.Chrome(PATH, options=opciones)
driver.get(URL)
time.sleep(5)

texto=driver.find_element(By.XPATH, '//*[@id="__next"]/header/div[2]/nav/ul/li[5]/a') #accedemos a la tabla leaderboard
texto.click()
time.sleep(5)
try:
    texto=driver.find_element(By.XPATH, '//*[@id="qc-cmp2-ui"]/div[2]/div/button[2]') #aceptamos cookies
    texto.click()
    time.sleep(5)
except:
    pass

texto=driver.find_element(By.XPATH, '//*[@id="content-container"]/div[2]/div/div/div[2]/div/button') #desplegable region
texto.click()
time.sleep(5)

texto=driver.find_element(By.XPATH, '//*[@id="content-container"]/div[2]/div/div/div[2]/div/div/button[1]') #seleccionamos region   NA
texto.click()
time.sleep(10)
#recuperacion de las filas de los invocadores del ranking
ranking=driver.find_elements(By.CLASS_NAME, 'css-1kk0pwf')
time.sleep(5)

#recuperacion del link de cada uno de los invocadores de la lista
links_summ=[]
for e in driver.find_elements(By.CLASS_NAME, 'css-1kk0pwf'):
    links_summ.append(e.find_element(By.TAG_NAME, 'a').get_attribute('href'))
    
driver.quit()

# %% [markdown]
# ACCESO A CADA UNO DE LOS JUGADORES PARA RECOLECCION DE DATOS GENERALES

# %%
SUMMONERS=[]

# %%
CABECERA=['summoner','points','totalwins','totaldefeats']

# %%
SUMMONERS=Parallel(n_jobs=4, verbose=True)(delayed(summoners)(url) for url in links_summ)
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed: 15.7min finished

# %%
challenger=pd.DataFrame(SUMMONERS, columns=CABECERA)

# %%
challenger['points']=challenger.points.apply(quitaletras)
challenger['totalwins']=challenger.totalwins.apply(quitaletra)
challenger['totaldefeats']=challenger.totaldefeats.apply(quitaletra)
#trasformacioin del dato a numerico
challenger["points"]=challenger["points"].str.replace(',','')
challenger['points'] = challenger['points'].astype(int)
challenger['totalwins'] = challenger['totalwins'].astype(int)
challenger['totaldefeats'] = challenger['totaldefeats'].astype(int)

# %%
str_conn='mysql+pymysql://root:1234@localhost:3306/mad_scientist'
cursor=create_engine(str_conn)

# %%
challenger.to_sql(name='summoners', con=cursor, if_exists='append', index=False)

# %%
links_summ = links_summ[:2]

# %% [markdown]
# ACCESO A CADA UNO DE LOS JUGADORES PARA RECOLECCION DE DATOS POR PARTIDA

# %%
PARTIDAS=[]

# %%
CABECERA2=['summoner','result','time','killp','champion','item1','item2','item3','item4','item5','item6','kills','deaths','assists','cs']

# %%
summonermatches=Parallel(n_jobs=2, verbose=True)(delayed(partidasjugadas)(url) for url in links_summ)
# Out:
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   59.8s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   59.8s finished

# %%
listita=[]
for e in summonermatches:
    for i in e:        
        listita.append(i)

# %%
summonermatches_df=pd.DataFrame(listita, columns=CABECERA2)

# %%
summonermatches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   summoner  40 non-null     object
#  1   result    40 non-null     object
#  2   time      40 non-null     object
#  3   killp     40 non-null     object
#  4   champion  40 non-null     object
#  5   item1     40 non-null     object
#  6   item2     40 non-null     object
#  7   item3     40 non-null     object
#  8   item4     40 non-null     object
#  9   item5     40 non-null     object
#  10  item6     40 non-null     object
#  11  kills     40 non-null     object
#  12  deaths    40 non-null     object
#  13  assists   40 non-null     object
#  14  cs        40 non-null     object
# dtypes: object(15)
# memory usage: 4.8+ KB

# %%
summonermatches
# Out:
# [[['PwVx Hc9999na',
#    'Victory',
#    '22m:43s',
#    '79%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'Void Staff',
#    "Sorcerer's Shoes",
#    'Dark Seal',
#    'null',
#    '10 ',
#    ' 3 ',
#    ' 12',
#    '160'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '18m:23s',
#    '71%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    "Mejai's Soulstealer",
#    "Sorcerer's Shoes",
#    'null',
#    'null',
#    '8 ',
#    ' 2 ',
#    ' 9',
#    '125'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '18m:18s',
#    '52%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'Dark Seal',
#    "Sorcerer's Shoes",
#    'null',
#    'null',
#    '6 ',
#    ' 1 ',
#    ' 7',
#    '134'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '29m:57s',
#    '64%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'Void Staff',
#    'Oblivion Orb',
#    "Mejai's Soulstealer",
#    "Sorcerer's Shoes",
#    '11 ',
#    ' 1 ',
#    ' 16',
#    '255'],
#   ['PwVx Hc9999na',
#    'Defeat',
#    '22m:6s',
#    '100%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'Refillable Potion',
#    'Dark Seal',
#    "Sorcerer's Shoes",
#    'Blighting Jewel',
#    '7 ',
#    ' 6 ',
#    ' 5',
#    '145'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '22m:4s',
#    '58%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    "Banshee's Veil",
#    "Sorcerer's Shoes",
#    'Dark Seal',
#    'null',
#    '6 ',
#    ' 0 ',
#    ' 8',
#    '164'],
#   ['PwVx Hc9999na',
#    'Defeat',
#    '20m:25s',
#    '56%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    'Broken Stopwatch',
#    "Seeker's Armguard",
#    'Fiendish Codex',
#    "Sorcerer's Shoes",
#    'Dark Seal',
#    '4 ',
#    ' 2 ',
#    ' 1',
#    '168'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '24m:38s',
#    '52%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'Blighting Jewel',
#    'Dark Seal',
#    "Sorcerer's Shoes",
#    'Blasting Wand',
#    '9 ',
#    ' 0 ',
#    ' 7',
#    '167'],
#   ['PwVx Hc9999na',
#    'Defeat',
#    '15m:23s',
#    '29%',
#    'Rumble',
#    'Refillable Potion',
#    'Hextech Alternator',
#    'Dark Seal',
#    "Doran's Shield",
#    "Sorcerer's Shoes",
#    'Blasting Wand',
#    '1 ',
#    ' 4 ',
#    ' 1',
#    '87'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '30m:24s',
#    '64%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'Needlessly Large Rod',
#    "Sorcerer's Shoes",
#    'Void Staff',
#    "Mejai's Soulstealer",
#    '9 ',
#    ' 6 ',
#    ' 16',
#    '194'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '25m:3s',
#    '43%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'Refillable Potion',
#    'Dark Seal',
#    'null',
#    "Sorcerer's Shoes",
#    '4 ',
#    ' 4 ',
#    ' 11',
#    '185'],
#   ['PwVx Hc9999na',
#    'Defeat',
#    '29m:47s',
#    '89%',
#    'Rumble',
#    'Riftmaker',
#    'Broken Stopwatch',
#    'Demonic Embrace',
#    'Dark Seal',
#    "Sorcerer's Shoes",
#    "Seeker's Armguard",
#    '4 ',
#    ' 5 ',
#    ' 4',
#    '187'],
#   ['PwVx Hc9999na',
#    'Defeat',
#    '33m:43s',
#    '65%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'null',
#    "Sorcerer's Shoes",
#    'Oblivion Orb',
#    'Void Staff',
#    '5 ',
#    ' 7 ',
#    ' 8',
#    '192'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '15m:14s',
#    '69%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    'Broken Stopwatch',
#    "Sorcerer's Shoes",
#    "Mejai's Soulstealer",
#    'Amplifying Tome',
#    'null',
#    '6 ',
#    ' 0 ',
#    ' 5',
#    '95'],
#   ['PwVx Hc9999na',
#    'Defeat',
#    '21m:29s',
#    '69%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    "Mejai's Soulstealer",
#    'null',
#    'null',
#    "Sorcerer's Shoes",
#    '7 ',
#    ' 4 ',
#    ' 4',
#    '155'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '27m:23s',
#    '74%',
#    'Rumble',
#    'Demonic Embrace',
#    'Stopwatch',
#    "Mejai's Soulstealer",
#    "Seeker's Armguard",
#    'Riftmaker',
#    "Sorcerer's Shoes",
#    '10 ',
#    ' 3 ',
#    ' 15',
#    '215'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '24m:47s',
#    '61%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'Control Ward',
#    'Dark Seal',
#    "Sorcerer's Shoes",
#    'Void Staff',
#    '10 ',
#    ' 2 ',
#    ' 9',
#    '156'],
#   ['PwVx Hc9999na',
#    'Defeat',
#    '22m:36s',
#    '80%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'null',
#    "Sorcerer's Shoes",
#    'Void Staff',
#    'null',
#    '5 ',
#    ' 2 ',
#    ' 3',
#    '161'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '29m:26s',
#    '69%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'Blighting Jewel',
#    "Sorcerer's Shoes",
#    'Dark Seal',
#    'Blasting Wand',
#    '5 ',
#    ' 9 ',
#    ' 15',
#    '144'],
#   ['PwVx Hc9999na',
#    'Victory',
#    '34m:25s',
#    '83%',
#    'Rumble',
#    'Hextech Rocketbelt',
#    "Zhonya's Hourglass",
#    'Void Staff',
#    "Mejai's Soulstealer",
#    "Sorcerer's Shoes",
#    "Rabadon's Deathcap",
#    '11 ',
#    ' 2 ',
#    ' 19',
#    '248']],
#  [['Wakanda f0rever',
#    'Defeat',
#    '24m:58s',
#    '82%',
#    'Kindred',
#    'Plated Steelcaps',
#    'Kraken Slayer',
#    "Wit's End",
#    'Black Cleaver',
#    'null',
#    'null',
#    '8 ',
#    ' 6 ',
#    ' 6',
#    '199'],
#   ['Wakanda f0rever',
#    'Victory',
#    '30m:0s',
#    '62%',
#    'Viego',
#    'Plated Steelcaps',
#    'Divine Sunderer',
#    'Blade of The Ruined King',
#    "Wit's End",
#    'Guardian Angel',
#    'null',
#    '8 ',
#    ' 3 ',
#    ' 15',
#    '213'],
#   ['Wakanda f0rever',
#    'Defeat',
#    '24m:34s',
#    '57%',
#    'Viego',
#    'Slightly Magical Footwear',
#    'Divine Sunderer',
#    'Blade of The Ruined King',
#    'Hearthbound Axe',
#    'Null-Magic Mantle',
#    'Pickaxe',
#    '4 ',
#    ' 6 ',
#    ' 9',
#    '151'],
#   ['Wakanda f0rever',
#    'Victory',
#    '23m:47s',
#    '63%',
#    'Graves',
#    'Broken Stopwatch',
#    'Goredrinker',
#    'Umbral Glaive',
#    'Black Cleaver',
#    'Frozen Heart',
#    'Plated Steelcaps',
#    '10 ',
#    ' 2 ',
#    ' 15',
#    '212'],
#   ['Wakanda f0rever',
#    'Defeat',
#    '28m:44s',
#    '50%',
#    'Viego',
#    'Control Ward',
#    'Divine Sunderer',
#    'Blade of The Ruined King',
#    'Hearthbound Axe',
#    'Null-Magic Mantle',
#    'Plated Steelcaps',
#    '8 ',
#    ' 12 ',
#    ' 5',
#    '137'],
#   ['Wakanda f0rever',
#    'Victory',
#    '29m:41s',
#    '57%',
#    'Kindred',
#    'null',
#    'Kraken Slayer',
#    "Wit's End",
#    'Black Cleaver',
#    'Titanic Hydra',
#    'Plated Steelcaps',
#    '10 ',
#    ' 6 ',
#    ' 6',
#    '273'],
#   ['Wakanda f0rever',
#    'Defeat',
#    '22m:29s',
#    '81%',
#    'Viego',
#    'Plated Steelcaps',
#    'Divine Sunderer',
#    'Blade of The Ruined King',
#    'Hearthbound Axe',
#    'Null-Magic Mantle',
#    'Pickaxe',
#    '8 ',
#    ' 6 ',
#    ' 5',
#    '137'],
#   ['Wakanda f0rever',
#    'Defeat',
#    '24m:37s',
#    '80%',
#    'Viego',
#    'Broken Stopwatch',
#    'Divine Sunderer',
#    'Blade of The Ruined King',
#    "Wit's End",
#    'null',
#    'Plated Steelcaps',
#    '11 ',
#    ' 6 ',
#    ' 5',
#    '148'],
#   ['Wakanda f0rever',
#    'Victory',
#    '30m:45s',
#    '67%',
#    'Graves',
#    'Plated Steelcaps',
#    'Goredrinker',
#    'Umbral Glaive',
#    'Black Cleaver',
#    "Warden's Mail",
#    'Glacial Buckler',
#    '6 ',
#    ' 10 ',
#    ' 14',
#    '225'],
#   ['Wakanda f0rever',
#    'Victory',
#    '22m:49s',
#    '52%',
#    'Viego',
#    'Plated Steelcaps',
#    'Divine Sunderer',
#    'Blade of The Ruined King',
#    'Hearthbound Axe',
#    'Null-Magic Mantle',
#    'Pickaxe',
#    '10 ',
#    ' 3 ',
#    ' 7',
#    '176'],
#   ['Wakanda f0rever',
#    'Victory',
#    '36m:46s',
#    '66%',
#    'Sejuani',
#    "Anathema's Chains",
#    'Control Ward',
#    'Frostfire Gauntlet',
#    'Frozen Heart',
#    'Bramble Vest',
#    'Ionian Boots of Lucidity',
#    '3 ',
#    ' 7 ',
#    ' 20',
#    '144'],
#   ['Wakanda f0rever',
#    'Victory',
#    '22m:1s',
#    '53%',
#    'Viego',
#    'null',
#    'Blade of The Ruined King',
#    'Frostfire Gauntlet',
#    "Wit's End",
#    'null',
#    'Plated Steelcaps',
#    '11 ',
#    ' 1 ',
#    ' 6',
#    '140'],
#   ['Wakanda f0rever',
#    'Victory',
#    '19m:37s',
#    '74%',
#    'Viego',
#    "Mercury's Treads",
#    'Blade of The Ruined King',
#    'Frostfire Gauntlet',
#    'Hearthbound Axe',
#    'null',
#    'Pickaxe',
#    '14 ',
#    ' 4 ',
#    ' 9',
#    '120'],
#   ['Wakanda f0rever',
#    'Defeat',
#    '23m:18s',
#    '58%',
#    'Kindred',
#    'Plated Steelcaps',
#    'Kraken Slayer',
#    "Wit's End",
#    "Caulfield's Warhammer",
#    'null',
#    'null',
#    '5 ',
#    ' 6 ',
#    ' 2',
#    '139'],
#   ['Wakanda f0rever',
#    'Victory',
#    '32m:3s',
#    '71%',
#    'Graves',
#    'Plated Steelcaps',
#    'Goredrinker',
#    'Umbral Glaive',
#    'Black Cleaver',
#    'Frozen Heart',
#    'Guardian Angel',
#    '15 ',
#    ' 2 ',
#    ' 7',
#    '273'],
#   ['Wakanda f0rever',
#    'Victory',
#    '34m:38s',
#    '79%',
#    'Akali',
#    "Zhonya's Hourglass",
#    'Hextech Rocketbelt',
#    'Shadowflame',
#    'Morellonomicon',
#    'null',
#    "Sorcerer's Shoes",
#    '10 ',
#    ' 8 ',
#    ' 12',
#    '240'],
#   ['Wakanda f0rever',
#    'Victory',
#    '32m:39s',
#    '85%',
#    'Viego',
#    'Stopwatch',
#    'Deicide',
#    "Wit's End",
#    'Force of Nature',
#    'Blade of The Ruined King',
#    "Mercury's Treads",
#    '13 ',
#    ' 1 ',
#    ' 10',
#    '242'],
#   ['Wakanda f0rever',
#    'Victory',
#    '26m:50s',
#    '73%',
#    'Kindred',
#    'Plated Steelcaps',
#    'Kraken Slayer',
#    "Wit's End",
#    'Titanic Hydra',
#    "Caulfield's Warhammer",
#    'Kindlegem',
#    '13 ',
#    ' 6 ',
#    ' 14',
#    '186'],
#   ['Wakanda f0rever',
#    'Victory',
#    '22m:36s',
#    '47%',
#    'Viego',
#    'Broken Stopwatch',
#    'Divine Sunderer',
#    'Blade of The Ruined King',
#    'Chain Vest',
#    'null',
#    "Mercury's Treads",
#    '4 ',
#    ' 5 ',
#    ' 10',
#    '143'],
#   ['Wakanda f0rever',
#    'Victory',
#    '19m:13s',
#    '65%',
#    'Taliyah',
#    "Zhonya's Hourglass",
#    'null',
#    "Luden's Tempest",
#    'Shadowflame',
#    'null',
#    "Sorcerer's Shoes",
#    '11 ',
#    ' 1 ',
#    ' 4',
#    '169']]]

# %%
summonermatches_df['kills']=summonermatches_df.kills.apply(quitaespacios)
summonermatches_df['deaths']=summonermatches_df.deaths.apply(quitaespacios)
summonermatches_df['assists']=summonermatches_df.assists.apply(quitaespacios)
summonermatches_df['killp']=summonermatches_df.killp.apply(quitaletra)
summonermatches_df['time'] = summonermatches_df.time.apply(horita)
#trasformacioin del dato a numerico
summonermatches_df['kills'] = summonermatches_df['kills'].astype(int)
summonermatches_df['deaths'] = summonermatches_df['deaths'].astype(int)
summonermatches_df['assists'] = summonermatches_df['assists'].astype(int)
summonermatches_df['cs'] = summonermatches_df['cs'].astype(int)
summonermatches_df['killp'] = summonermatches_df['killp'].astype(int)

# %%
summonermatches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   summoner  40 non-null     object
#  1   result    40 non-null     object
#  2   time      40 non-null     object
#  3   killp     40 non-null     int32
#  4   champion  40 non-null     object
#  5   item1     40 non-null     object
#  6   item2     40 non-null     object
#  7   item3     40 non-null     object
#  8   item4     40 non-null     object
#  9   item5     40 non-null     object
#  10  item6     40 non-null     object
#  11  kills     40 non-null     int32
#  12  deaths    40 non-null     int32
#  13  assists   40 non-null     int32
#  14  cs        40 non-null     int32
# dtypes: int32(5), object(10)
# memory usage: 4.0+ KB

# %%
str_conn='mysql+pymysql://root:1234@localhost:3306/mad_scientist'
cursor=create_engine(str_conn)

# %%
summonermatches_df.to_sql(name='partidas', con=cursor, if_exists='append', index=False)
