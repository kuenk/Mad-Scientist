# %%
import requests as req
key='RGAPI-85b5caab-c6be-4477-a5c0-11056f9e6d58'

# %%
PUUID = 'dPlcdqvewZsZk3kWq07wL5TUwMOtdEsJ4PdEyhbp4zzL-rwPJkwXV5MIAgLbQjWl6cREeU--GgAwKQ'
#URL=f"https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/{PUUID}/ids?start=0&count=100"
URL_summ=f"https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/{PUUID}/ids?start=0&count=100&api_key={key}"

# %%
partidas=req.get(URL_summ)

# %%
aux=partidas.json()[0]

# %%
URL_match=f"https://americas.api.riotgames.com/lol/match/v5/matches/{aux}?api_key={key}"
match=req.get(URL_match)

# %%
match
# Out:
# <Response [200]>

# %%
match.json()
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_4504803864',
#   'participants': ['O0FlzoX_baKLyKTQRypqdNLnuZW-Fvdnkv0oCcckog-JSWMCDgZ4L2VZzTcYMfvJSQ2WLRkWrvVdBw',
#    'RvgQtnRrLio_SRVTpiy8ff7w0I1lQp8qxW3xko4Xg1Vyf_GTnvjDD79_pEqCnyPG-xBeOgBb1terIw',
#    '0D_cDVUd37zBuzVdWzwov2fzzlXXiTOO7d45QCPU6scKnOOr08tp3T6ogX0BML_23yNi-iJSldTiVw',
#    '3Ou7-97j6m4oEBkMfEAgQMuXojmRpe3aAk2M65iRztiYbfFuoMDkSAOC9e0f-WN-nuGn6BN3bX-oJA',
#    'lt7aDAw4lsFmpixVNeppoQDAPJhXcZVZjPWHYNeajYR6T6nC22Cotn6wGUI3shsO1b31ED4CDQsWRw',
#    'Q-mu-7gU19oDhaaXKGD1EI2RI-GBFkO5qLS4_aEOtCN29i8BDBhceBG_sJZadKXuRGi0yaL4pYxMWg',
#    '4fPrP4WFn_cRnH9rlix1o0BjxPUzHj7O7nhOTx8LaOHfJYtyuKW9ZCKYi34m22CFMGAwUtmu4F0BQA',
#    'FCqoGT-P3c7Fc5pWfjssxgjOHq6KKr59UjViHT0NtkyIazNGlok5uvjlpHJqvYCHJNcsYxAsJVwU2w',
#    'dPlcdqvewZsZk3kWq07wL5TUwMOtdEsJ4PdEyhbp4zzL-rwPJkwXV5MIAgLbQjWl6cREeU--GgAwKQ',
#    'F360UMFlSH7xHTNiPi2sb77CgKCk4J_e-M_ksF9gGsqJgvlx3ffFjEInwMCioANljQNAFzkNPvcJmA']},
#  'info': {'gameCreation': 1669696773129,
# ...
